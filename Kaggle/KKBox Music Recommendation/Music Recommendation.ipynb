# %%
"""
The training dataset contains 30755 unique users who contribute to the entire training data of 
song listens. And the test set has 25131 unique users who contribute to the entiriety of the test set.

This goes on to show the importance of user bias in this model. To predict if a known user would listen to 
a song again, we cant ignore the other songs he/she has liked and re-listened before and would need to 
factor that in as well.

This makes the problem a good fit for a latent factor model where we take user and product bias into account,
to make a decision.


However, lets first start with a simpler model by removing the msno(user id) column. This way, we would be
predicting if a song is trendy and is good for a relisten by any user, not just the user in question. 
Since the user bias would not be taken into account, we would just predict if a song is probable for a 
relisten.

"""

# %%
# %matplotlib inline
import operator
import numpy as np
import pandas as pd
import xgboost as xgb
import lightgbm as lgb
from collections import Counter
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
pd.set_option("display.max_columns",40)

# %%
def read_data(file_path):
    return pd.read_csv(file_path)

# %%
def get_merged_df_with_user_song_info(df, user_data_df, song_data_df, song_aux_data_df):
    """
    Join all the dataframes(on matching columns) to form a single merged dataframe with all the user and song 
    information
    """
    agg_user_df = pd.merge(left=df, right=user_data_df, how='left')
    
    agg_user_song_df = pd.merge(left=agg_user_df, right=song_data_df, how='left')
    
    merged_df = pd.merge(left=agg_user_song_df, right=song_aux_data_df, how='left')
    
    return merged_df

# %%
def data_massaging(df):
    
    df = df.assign(
        unique_user_id=(df['msno']).astype('category').cat.codes,
        unique_song_id=(df['song_id']).astype('category').cat.codes,
    )
    
    # drop the msno(user id) field for the current, user-agnostic, simpler model
    df = df.drop('msno', 1)
    df = df.drop('song_id', 1)    
    df = df.drop('id', 1) if 'id' in df.columns else df
    df = df.drop('isrc', 1)
    
    df['registration_init_year'] = df['registration_init_time'].apply(lambda x: str(x)[:4]).astype('int64')
    df['registration_init_month'] = df['registration_init_time'].apply(lambda x: str(x)[4:6]).astype('int64')
    df['registration_init_date'] = df['registration_init_time'].apply(lambda x: str(x)[6:8]).astype('int64')
    
    df['expiration_year'] = df['expiration_date'].apply(lambda x: str(x)[:4]).astype('int64')
    df['expiration_month'] = df['expiration_date'].apply(lambda x: str(x)[4:6]).astype('int64')
    df['expiration_date_'] = df['expiration_date'].apply(lambda x: str(x)[6:8]).astype('int64')
    
    df['age_of_account'] = df['expiration_year'].apply(int) - df['registration_init_year'].apply(int)
    
    df = df.drop('registration_init_time', 1)
    df = df.drop('expiration_date', 1)

    # missing data
    string_missing_value_columns = [
        'lyricist', 'gender', 'composer', 'source_screen_name', 'genre_ids',
        'source_type', 'source_system_tab', 'name', 'language', 'artist_name'
    ]
    numeric_missing_value_columns = ['song_length']
    
    for column in string_missing_value_columns:
        df[column] = df[column].fillna('missing')
    for column in numeric_missing_value_columns:
        df[column] = df[column].fillna(df[column].median())
        
    
    def genre_id_count(genre_ids):
        return 0 if genre_ids == 'missing' else genre_ids.count('|') + 1
    df['genre_count'] = df['genre_ids'].apply(genre_id_count)

    def composer_count(composer):
        return 0 if composer == 'missing' else composer.count('|') + 1
    df['composer_count'] = df['composer'].apply(composer_count)

    def lyricist_count(lyricist):
        return 0 if lyricist == 'missing' else lyricist.count('|') + 1
    df['lyricist_count'] = df['lyricist'].apply(lyricist_count)

    def artist_count(artist_name):
        if artist_name == 'missing':   return 0
        elif artist_name == 'Various Artists':   return 2
        else:   return 1
    df['artist_count'] = df['artist_name'].apply(artist_count)
    
    df['ranked_artist'] = df.groupby('artist_name')['artist_name'].transform(pd.Series.value_counts)
    
    
    scaler = MinMaxScaler()
    df[['song_length']] = scaler.fit_transform(df[['song_length']])

    # fix dtypes
    categorical_columns = [
        'source_system_tab', 'source_screen_name', 'source_type', 'city', 'gender', 
        'registered_via', 'genre_ids', 'artist_name', 'composer', 'lyricist', 'language', 'name'
    ]
    for column in categorical_columns:
        df[column] = df[column].astype('category')
        
    return df

# %%
def generate_dummies_for_data(train_X, test_X):
    limit = train_X.shape[0]
    
    df = pd.concat([train_X, test_X])
    dummy_df = pd.get_dummies(df)
    
    dummyfied_train_X = dummy_df.iloc[:, :limit + 1]
    dummyfied_test_X = dummy_df.iloc[:, limit + 1:]
    
    assert dummyfied_train_X.shape[0] == train_X.shape[0]
    assert dummyfied_test_X.shape[0] == test_X.shape[0]
    assert dummyfied_train_X.shape[1] == dummyfied_test_X.shape[1]
    
    return dummyfied_train_X, dummyfied_test_X

# %%
def grid_search_report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
def lgbm_classifier(train_X, train_y, test_X, test_y=None, **kwargs):
    params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': {'auc'},
        'num_leaves': 80,
        'learning_rate': 0.1,
        'subsample': 0.8,
        'bagging_freq': 5,
        'max_bin': 256,
        'min_samples_split': 500,
        'min_samples_leaf': 50,
        'max_depth': 10
    }
    lgb_train = lgb.Dataset(train_X, train_y.values)

    try:
        lgb_val = lgb.Dataset(test_X, test_y.values, reference=lgb_train)    
        gbm = lgb.train(
            params,
            lgb_train,
            num_boost_round=200,
            valid_sets=lgb_val,
            early_stopping_rounds=5
        )    
        pred_y = gbm.predict(test_X, num_iteration=gbm.best_iteration)
        print('The rmse of prediction is:', mean_squared_error(test_y, pred_y) ** 0.5)
        print('The AUC is:', roc_auc_score(test_y, pred_y))
    except:
        gbm = lgb.train(
            params,
            lgb_train,
            num_boost_round=300
        )
        pred_y = gbm.predict(test_X, num_iteration=gbm.best_iteration)
        
    return pred_y

# %%
training_data = 'train.csv'
test_data = 'test.csv'
song_data = 'songs.csv'
user_data = 'members.csv'
song_aux_data = 'song_extra_info.csv'

# %%
# read data
train_X = read_data(training_data)
test_X = read_data(test_data)

song_data_df = read_data(song_data)
user_data_df = read_data(user_data)
song_aux_data_df = read_data(song_aux_data)

# %%
test_data_ids = test_X['id']

train_merged_df = get_merged_df_with_user_song_info(
    train_X,
    user_data_df,
    song_data_df,
    song_aux_data_df
)

test_merged_df = get_merged_df_with_user_song_info(
    test_X,
    user_data_df,
    song_data_df,
    song_aux_data_df
)

# %%
refined_train_X = data_massaging(train_merged_df)
refined_test_X = data_massaging(test_merged_df)

refined_train_y = refined_train_X['target']
refined_train_X = refined_train_X.drop('target', axis=1)

# %%
refined_train_X.to_csv('refined_train_X.csv')
refined_train_y.to_csv('refined_train_y.csv')
refined_test_X.to_csv('refined_test_X.csv')

# %%
# split the training data into train and validation sets into 2/3 and 1/3
ref_train_X, ref_val_X, ref_train_y, ref_val_y = train_test_split(
    refined_train_X,
    refined_train_y,
    test_size=0.33,
    random_state=42,
)

# %%
grid_search_params = {
    'boosting_type': ['dart'],
    'objective': ['binary'],
    'metric': ['auc'],
    'num_leaves': [31],
    'learning_rate': [0.1],
    'feature_fraction': [0.9],
    'bagging_fraction': [0.8],
    'bagging_freq': [5],
    'min_samples_split': [500],
    'min_samples_leaf': [50],
    'max_depth': [8],
    'max_features': ['sqrt'],
    'subsample': [0.8]
}

# %%
grid_search = GridSearchCV(
    estimator=lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, min_samples_split=500, min_samples_leaf=50, 
                                 max_depth=8, max_features='sqrt', subsample=0.8, random_state=10), 
    param_grid=grid_search_params,
    scoring='roc_auc',
    iid=False,
    cv=5
)

grid_search.fit(refined_train_X, refined_train_y)
grid_search_report(grid_search.cv_results_)
# Out:
# Model with rank: 1
# Mean validation score: 0.676 (std: 0.046)
# Parameters: {'n_estimators': 50}
#
# Model with rank: 2
# Mean validation score: 0.676 (std: 0.047)
# Parameters: {'n_estimators': 100}
#
# Model with rank: 3
# Mean validation score: 0.676 (std: 0.047)
# Parameters: {'n_estimators': 150}

# %%
# training
pred_val_y = lgbm_classifier(ref_train_X, ref_train_y, ref_val_X, ref_val_y)
# Out:
# [1]	valid_0's auc: 0.682322
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 0.684582
# [3]	valid_0's auc: 0.685638
# [4]	valid_0's auc: 0.687767
# [5]	valid_0's auc: 0.689404
# [6]	valid_0's auc: 0.690068
# [7]	valid_0's auc: 0.690793
# [8]	valid_0's auc: 0.691736
# [9]	valid_0's auc: 0.692206
# [10]	valid_0's auc: 0.692732
# [11]	valid_0's auc: 0.69398
# [12]	valid_0's auc: 0.694369
# [13]	valid_0's auc: 0.694859
# [14]	valid_0's auc: 0.695286
# [15]	valid_0's auc: 0.695729
# [16]	valid_0's auc: 0.696435
# [17]	valid_0's auc: 0.696946
# [18]	valid_0's auc: 0.697625
# [19]	valid_0's auc: 0.697949
# [20]	valid_0's auc: 0.698182
# [21]	valid_0's auc: 0.698443
# [22]	valid_0's auc: 0.699051
# [23]	valid_0's auc: 0.699519
# [24]	valid_0's auc: 0.699886
# [25]	valid_0's auc: 0.700156
# [26]	valid_0's auc: 0.700486
# [27]	valid_0's auc: 0.700778
# [28]	valid_0's auc: 0.701404
# [29]	valid_0's auc: 0.701518
# [30]	valid_0's auc: 0.701772
# [31]	valid_0's auc: 0.702223
# [32]	valid_0's auc: 0.702426
# [33]	valid_0's auc: 0.702623
# [34]	valid_0's auc: 0.702865
# [35]	valid_0's auc: 0.703161
# [36]	valid_0's auc: 0.703663
# [37]	valid_0's auc: 0.703835
# [38]	valid_0's auc: 0.703981
# [39]	valid_0's auc: 0.704121
# [40]	valid_0's auc: 0.704319
# [41]	valid_0's auc: 0.704532
# [42]	valid_0's auc: 0.704653
# [43]	valid_0's auc: 0.704732
# [44]	valid_0's auc: 0.704833
# [45]	valid_0's auc: 0.704925
# [46]	valid_0's auc: 0.70496
# [47]	valid_0's auc: 0.705049
# [48]	valid_0's auc: 0.705127
# [49]	valid_0's auc: 0.705434
# [50]	valid_0's auc: 0.705627
# [51]	valid_0's auc: 0.705749
# [52]	valid_0's auc: 0.705763
# [53]	valid_0's auc: 0.705899
# [54]	valid_0's auc: 0.705964
# [55]	valid_0's auc: 0.705998
# [56]	valid_0's auc: 0.706009
# [57]	valid_0's auc: 0.706023
# [58]	valid_0's auc: 0.706067
# [59]	valid_0's auc: 0.706178
# [60]	valid_0's auc: 0.706258
# [61]	valid_0's auc: 0.706277
# [62]	valid_0's auc: 0.70629
# [63]	valid_0's auc: 0.706304
# [64]	valid_0's auc: 0.706358
# [65]	valid_0's auc: 0.706374
# [66]	valid_0's auc: 0.706389
# [67]	valid_0's auc: 0.706407
# [68]	valid_0's auc: 0.706415
# [69]	valid_0's auc: 0.706419
# [70]	valid_0's auc: 0.706543
# [71]	valid_0's auc: 0.706559
# [72]	valid_0's auc: 0.706589
# [73]	valid_0's auc: 0.706601
# [74]	valid_0's auc: 0.706658
# [75]	valid_0's auc: 0.706818
# [76]	valid_0's auc: 0.706831
# [77]	valid_0's auc: 0.70684
# [78]	valid_0's auc: 0.706898
# [79]	valid_0's auc: 0.70714
# [80]	valid_0's auc: 0.707159
# [81]	valid_0's auc: 0.707171
# [82]	valid_0's auc: 0.707182
# [83]	valid_0's auc: 0.707218
# [84]	valid_0's auc: 0.707369
# [85]	valid_0's auc: 0.70756
# [86]	valid_0's auc: 0.707571
# [87]	valid_0's auc: 0.707573
# [88]	valid_0's auc: 0.707593
# [89]	valid_0's auc: 0.707734
# [90]	valid_0's auc: 0.707745
# [91]	valid_0's auc: 0.707752
# [92]	valid_0's auc: 0.707759
# [93]	valid_0's auc: 0.707772
# [94]	valid_0's auc: 0.707794
# [95]	valid_0's auc: 0.707823
# [96]	valid_0's auc: 0.707833
# [97]	valid_0's auc: 0.707845
# [98]	valid_0's auc: 0.707857
# [99]	valid_0's auc: 0.707881
# [100]	valid_0's auc: 0.707892
# [101]	valid_0's auc: 0.707899
# [102]	valid_0's auc: 0.707905
# [103]	valid_0's auc: 0.707937
# [104]	valid_0's auc: 0.707946
# [105]	valid_0's auc: 0.708009
# [106]	valid_0's auc: 0.708018
# [107]	valid_0's auc: 0.708025
# [108]	valid_0's auc: 0.708026
# [109]	valid_0's auc: 0.708047
# [110]	valid_0's auc: 0.708298
# [111]	valid_0's auc: 0.708302
# [112]	valid_0's auc: 0.708309
# [113]	valid_0's auc: 0.708334
# [114]	valid_0's auc: 0.708331
# [115]	valid_0's auc: 0.70833
# [116]	valid_0's auc: 0.708337
# [117]	valid_0's auc: 0.70834
# [118]	valid_0's auc: 0.708353
# [119]	valid_0's auc: 0.708375
# [120]	valid_0's auc: 0.708376
# [121]	valid_0's auc: 0.708382
# [122]	valid_0's auc: 0.708385
# [123]	valid_0's auc: 0.708412
# [124]	valid_0's auc: 0.708471
# [125]	valid_0's auc: 0.708634
# [126]	valid_0's auc: 0.708638
# [127]	valid_0's auc: 0.708669
# [128]	valid_0's auc: 0.708751
# [129]	valid_0's auc: 0.708767
# [130]	valid_0's auc: 0.708769
# [131]	valid_0's auc: 0.708771
# [132]	valid_0's auc: 0.708773
# [133]	valid_0's auc: 0.708938
# [134]	valid_0's auc: 0.708994
# [135]	valid_0's auc: 0.709011
# [136]	valid_0's auc: 0.709015
# [137]	valid_0's auc: 0.709021
# [138]	valid_0's auc: 0.709089
# [139]	valid_0's auc: 0.70909
# [140]	valid_0's auc: 0.709103
# [141]	valid_0's auc: 0.709108
# [142]	valid_0's auc: 0.709114
# [143]	valid_0's auc: 0.709111
# [144]	valid_0's auc: 0.709124
# [145]	valid_0's auc: 0.709284
# [146]	valid_0's auc: 0.709291
# [147]	valid_0's auc: 0.709297
# [148]	valid_0's auc: 0.709313
# [149]	valid_0's auc: 0.70938
# [150]	valid_0's auc: 0.709486
# [151]	valid_0's auc: 0.709485
# [152]	valid_0's auc: 0.709485
# [153]	valid_0's auc: 0.709516
# [154]	valid_0's auc: 0.709525
# [155]	valid_0's auc: 0.709574
# [156]	valid_0's auc: 0.709578
# [157]	valid_0's auc: 0.709577
# [158]	valid_0's auc: 0.709583
# [159]	valid_0's auc: 0.709581
# [160]	valid_0's auc: 0.709603
# [161]	valid_0's auc: 0.709607
# [162]	valid_0's auc: 0.709609
# [163]	valid_0's auc: 0.709611
# [164]	valid_0's auc: 0.709674
# [165]	valid_0's auc: 0.709713
# [166]	valid_0's auc: 0.709712
# [167]	valid_0's auc: 0.70971
# [168]	valid_0's auc: 0.709735
# [169]	valid_0's auc: 0.709754
# [170]	valid_0's auc: 0.709791
# [171]	valid_0's auc: 0.709792
# [172]	valid_0's auc: 0.709794
# [173]	valid_0's auc: 0.709807
# [174]	valid_0's auc: 0.709813
# [175]	valid_0's auc: 0.709837
# [176]	valid_0's auc: 0.709838
# [177]	valid_0's auc: 0.709837
# [178]	valid_0's auc: 0.709841
# [179]	valid_0's auc: 0.709851
# [180]	valid_0's auc: 0.709861
# [181]	valid_0's auc: 0.709867
# [182]	valid_0's auc: 0.709868
# [183]	valid_0's auc: 0.709864
# [184]	valid_0's auc: 0.709863
# [185]	valid_0's auc: 0.709863
# [186]	valid_0's auc: 0.709868
# [187]	valid_0's auc: 0.709873
# [188]	valid_0's auc: 0.709878
# [189]	valid_0's auc: 0.709937
# [190]	valid_0's auc: 0.71011
# [191]	valid_0's auc: 0.71011
# [192]	valid_0's auc: 0.710119
# [193]	valid_0's auc: 0.710396
# [194]	valid_0's auc: 0.710631
# [195]	valid_0's auc: 0.71063
# [196]	valid_0's auc: 0.710631
# [197]	valid_0's auc: 0.710643
# [198]	valid_0's auc: 0.710646
# [199]	valid_0's auc: 0.710657
# [200]	valid_0's auc: 0.710708
# ('The rmse of prediction is:', 0.46521516709745087)
# ('The AUC is:', 0.71070820099295373)

# %%
# testing
pred_test_y = lgbm_classifier(refined_train_X, refined_train_y, refined_test_X, None)

# %%
predictions = pd.DataFrame()
predictions['id'] = test_data_ids
predictions['target'] = pred_test_y
predictions.to_csv('KKBox_submission.csv', index=False)

# %%
refined_train_X
# Out:
#         source_system_tab    source_screen_name          source_type city  bd  \
# 0                 explore               Explore      online-playlist    1   0
# 1              my library   Local playlist more       local-playlist   13  24
# 2              my library   Local playlist more       local-playlist   13  24
# 3              my library   Local playlist more       local-playlist   13  24
# 4                 explore               Explore      online-playlist    1   0
# 5                 explore               Explore      online-playlist    1   0
# 6              my library   Local playlist more       local-playlist   13  24
# 7                 explore               Explore      online-playlist    1   0
# 8              my library   Local playlist more        local-library   15  26
# 9              my library   Local playlist more        local-library   15  26
# 10             my library   Local playlist more        local-library   15  26
# 11             my library   Local playlist more        local-library   15  26
# 12             my library               missing  top-hits-for-artist    1   0
# 13             my library   Local playlist more        local-library    5   0
# 14             my library   Local playlist more       local-playlist    1   0
# 15             my library   Local playlist more        local-library    5   0
# 16             my library            My library       local-playlist    1   0
# 17             my library            My library       local-playlist    1   0
# 18             my library               missing  top-hits-for-artist    1   0
# 19             my library   Local playlist more        local-library    9  27
# 20             my library   Local playlist more        local-library    9  27
# 21             my library   Local playlist more        local-library    9  27
# 22             my library   Local playlist more        local-library    9  27
# 23             my library  Online playlist more      online-playlist   15  18
# 24             my library  Online playlist more      online-playlist   15  18
# 25             my library  Online playlist more      online-playlist   15  18
# 26             my library  Online playlist more      online-playlist   15  18
# 27             my library   Local playlist more        local-library    1   0
# 28             my library   Local playlist more        local-library    1   0
# 29             my library   Local playlist more        local-library   13  34
# ...                   ...                   ...                  ...  ...  ..
# 7377388        my library   Local playlist more        local-library   15  27
# 7377389        my library   Local playlist more        local-library   15  27
# 7377390        my library   Local playlist more       local-playlist   15  21
# 7377391        my library   Local playlist more        local-library   13  41
# 7377392            search            Album more                album    6  23
# 7377393            search            Album more                album    6  23
# 7377394        my library   Local playlist more        local-library   15  22
# 7377395        my library   Local playlist more        local-library   15  22
# 7377396        my library   Local playlist more        local-library   15  22
# 7377397        my library   Local playlist more        local-library   13  18
# 7377398        my library   Local playlist more       local-playlist   15  27
# 7377399        my library   Local playlist more       local-playlist   15  27
# 7377400        my library   Local playlist more       local-playlist   15  27
# 7377401        my library   Local playlist more       local-playlist   22  29
# 7377402          discover               missing  song-based-playlist   22  37
# 7377403          discover               missing  song-based-playlist   22  37
# 7377404          discover               missing  song-based-playlist   22  37
# 7377405        my library   Local playlist more        local-library    4  28
# 7377406           explore  Online playlist more      online-playlist    1   0
# 7377407        my library   Local playlist more        local-library    1   0
# 7377408            search                Search                 song    1   0
# 7377409            search                Search                 song    1   0
# 7377410        my library   Local playlist more        local-library    1   0
# 7377411        my library   Local playlist more        local-library    1   0
# 7377412        my library   Local playlist more        local-library    1   0
# 7377413        my library   Local playlist more       local-playlist    4  26
# 7377414            search                Search                 song    1   0
# 7377415            search                Search                 song    1   0
# 7377416          discover        Discover Genre      online-playlist    5   0
# 7377417          discover        Discover Genre      online-playlist    5   0
#
#           gender registered_via  song_length genre_ids  \
# 0        missing              7     0.018901       359
# 1         female              9     0.026100      1259
# 2         female              9     0.020645      1259
# 3         female              9     0.023420      1019
# 4        missing              7     0.017180      1011
# 5        missing              7     0.022710      1259
# 6         female              9     0.021068       465
# 7        missing              7     0.016564      1011
# 8           male              9     0.025582      2022
# 9           male              9     0.023592       465
# 10          male              9     0.020510       465
# 11          male              9     0.020571       465
# 12       missing              9     0.025685       465
# 13       missing              9     0.023234       458
# 14       missing              9     0.019259   465|458
# 15       missing              9     0.022048       465
# 16       missing              9     0.022801       465
# 17       missing              9     0.023823       458
# 18       missing              9     0.024363       465
# 19        female              9     0.022173       465
# 20        female              9     0.017368       458
# 21        female              9     0.022720       465
# 22        female              9     0.023619       465
# 23          male              4     0.016761      2022
# 24          male              4     0.026789      2022
# 25          male              4     0.011967      2022
# 26          male              4     0.028184       465
# 27       missing              7     0.019586       465
# 28       missing              7     0.024871       465
# 29          male              9     0.022782   missing
# ...          ...            ...          ...       ...
# 7377388     male              9     0.025257       451
# 7377389     male              9     0.023070       458
# 7377390   female              3     0.027768       458
# 7377391     male              7     0.024611       458
# 7377392     male              9     0.026769       465
# 7377393     male              9     0.022820       465
# 7377394     male              9     0.020628       465
# 7377395     male              9     0.020355       458
# 7377396     male              9     0.028124       465
# 7377397     male              9     0.019076       465
# 7377398     male              9     0.019170       465
# 7377399     male              9     0.020894       465
# 7377400     male              9     0.028589       465
# 7377401   female              3     0.021464       465
# 7377402   female              9     0.015191      1609
# 7377403   female              9     0.020596      1609
# 7377404   female              9     0.016923      1609
# 7377405   female              9     0.018721       359
# 7377406  missing              7     0.018121       786
# 7377407  missing              7     0.021549       458
# 7377408  missing              7     0.016042       921
# 7377409  missing              7     0.014929       921
# 7377410  missing              7     0.015879       465
# 7377411  missing              7     0.019637       465
# 7377412  missing              7     0.021049       465
# 7377413   female              9     0.024567      1259
# 7377414  missing              7     0.020830       465
# 7377415  missing              7     0.023677       465
# 7377416  missing              9     0.048179      2122
# 7377417  missing              9     0.023283       212
#
#                                           artist_name  \
# 0                                            Bastille
# 1                                     Various Artists
# 2                                                 Nas
# 3                                            Soundway
# 4                                         Brett Young
# 5                                           Desiigner
# 6                                     BIGBANG TAEYANG
# 7                                        Thomas Rhett
# 8                                         OneRepublic
# 9                                         OneRepublic
# 10                                   Lindsey Stirling
# 11                                         嚴爵 (Yen-j)
# 12                                       林俊傑 (JJ Lin)
# 13                                     周杰倫 (Jay Chou)
# 14                                       林俊傑 (JJ Lin)
# 15                                    Various Artists
# 16                                      吳汶芳 (Fang Wu)
# 17                                         aMEI (張惠妹)
# 18                                       林俊傑 (JJ Lin)
# 19                                    孫燕姿 (Yanzi Sun)
# 20                                   陳星翰 (Starr Chen)
# 21                                    莫文蔚 (Karen Mok)
# 22                                       五月天 (Mayday)
# 23                                        John Lennon
# 24                                        John Lennon
# 25                                        The Beatles
# 26       Pleasantville -Music From The Motion Picture
# 27                                      Justin Bieber
# 28                                              S.H.E
# 29                                  韋禮安 (William Wei)
# ...                                               ...
# 7377388                               許茹芸 (Valen Hsu)
# 7377389                                 孫盛希 (Shi Shi)
# 7377390                                      Eric 周興哲
# 7377391                          動力火車 (Power Station)
# 7377392                                           王識賢
# 7377393                                           王識賢
# 7377394                               Various Artists
# 7377395                                 聽見下雨的聲音 電影原聲帶
# 7377396                               蘇打綠 (Sodagreen)
# 7377397                               孫燕姿 (Yanzi Sun)
# 7377398                                    aMEI (張惠妹)
# 7377399                                    aMEI (張惠妹)
# 7377400                                    aMEI (張惠妹)
# 7377401                                           張震嶽
# 7377402                                   MAJOR LAZER
# 7377403                                    Kesha|Zedd
# 7377404                                        Baauer
# 7377405                               Various Artists
# 7377406                                        寶寶水晶音樂
# 7377407                                          AMIT
# 7377408                               Various Artists
# 7377409                               Various Artists
# 7377410                                      Maroon 5
# 7377411                                      Maroon 5
# 7377412                                      Maroon 5
# 7377413                                       Dr. Dre
# 7377414                    R. City feat.  Adam Levine
# 7377415                兄弟本色G.U.T.S. (姚中仁、張震嶽、頑童MJ116)
# 7377416                             Brad Mehldau Trio
# 7377417                   Biréli Lagrène| Sylvain Luc
#
#                                                   composer  \
# 0                                     Dan Smith| Mark Crew
# 1                                                  missing
# 2                     N. Jones、W. Adams、J. Lordan、D. Ingle
# 3                                            Kwadwo Donkoh
# 4                  Brett Young| Kelly Archer| Justin Ebach
# 5                                 Sidney Selby| Adnan Khan
# 6                            TEDDY| DEE.P| Rebecca Johnson
# 7                   Thomas Rhett| Rhett Akins| Ben Hayslip
# 8                                              Ryan Tedder
# 9                                              Ryan Tedder
# 10                   Lindsey Stirling| Dia Frampton| SILAS
# 11                                                      嚴爵
# 12                                                     林俊傑
# 13                                                     周杰倫
# 14                                                  JJ Lin
# 15                                                   GAEMI
# 16                                                     吳汶芳
# 17                                               Wang Feng
# 18                                                  JJ Lin
# 19                                             Li Wei Song
# 20                                              Starr Chen
# 21                                             Skot Suyama
# 22                                                 missing
# 23                                             John Lennon
# 24                             John Lennon| Paul McCartney
# 25                             John Lennon| Paul McCartney
# 26                                                 missing
# 27       Justin Bieber| Terius Nash| Christopher Stewar...
# 28                                                     周杰倫
# 29                                                     韋禮安
# ...                                                    ...
# 7377388                                      Zhong Ping Ji
# 7377389                                                孫盛希
# 7377390                                          Eric Chou
# 7377391                                               張簡君偉
# 7377392                                            missing
# 7377393                                            missing
# 7377394                                 Han Seung Taek/ROZ
# 7377395                                                許叔男
# 7377396                                            missing
# 7377397                                        Lin Yi Feng
# 7377398                                                阿弟仔
# 7377399                                                梁思樺
# 7377400                                                丹戈爾
# 7377401                                                張震嶽
# 7377402                                            missing
# 7377403         Anton Zaslavski| Antonina Armato| T. Price
# 7377404                                            missing
# 7377405  Noah Feldshuh| Casey Harris| Sam Harris| A. Gr...
# 7377406                                            missing
# 7377407                                          Ai Li Shi
# 7377408                                 Lin-Manuel Miranda
# 7377409                                 Lin-Manuel Miranda
# 7377410                         J. Carmichael| Adam Levine
# 7377411  Kendrick Lamar| Benny Blanco| Adam Levine| Jac...
# 7377412  Ryan Tedder| Noel Zancanella| Adam Levine| Nat...
# 7377413  Andre R. Young| Melvin Charles Bradford| Shawn...
# 7377414  Theron Thomas| Timothy Thomas| Lukasz Gottwald...
# 7377415               姚中仁 MC HotDog 陳昱榕 Ｅ-SO 周文傑 KENZY 林睦淵
# 7377416                                            missing
# 7377417                  Robert Andrew Hyman| Cyndy Lauper
#
#                                                   lyricist language  \
# 0                                                  missing       52
# 1                                                  missing       52
# 2                                                  missing       52
# 3                                                  missing       -1
# 4                                                  missing       52
# 5                                                  missing       52
# 6                                           TEDDY| TAEYANG       31
# 7                                                  missing       52
# 8                                                  missing       52
# 9                                                  missing       52
# 10                                                 missing       52
# 11                                                      嚴爵        3
# 12                                                     林怡鳳        3
# 13                                                     周杰倫        3
# 14                                             Lin Yi Feng        3
# 15                               Ji Hoon/Roco of Rocoberry       31
# 16                                                     吳汶芳        3
# 17                                                 missing        3
# 18                                             Wang Ya Jun        3
# 19                                                Xiao Han        3
# 20                                                 missing        3
# 21                                                     李焯雄        3
# 22                                                 missing        3
# 23                                                 missing       52
# 24                                                 missing       52
# 25                                                 missing       52
# 26                                                 missing       52
# 27                                                 missing       52
# 28                                               Selina+李姚        3
# 29                                                     韋禮安        3
# ...                                                    ...      ...
# 7377388                                            missing        3
# 7377389                    蘇三毛\Molly Lin (妮可醬)@i-One Music        3
# 7377390                                        Xue-Man Rao        3
# 7377391                                                藍小邪        3
# 7377392                                            missing       10
# 7377393                                            missing       10
# 7377394                                            missing       31
# 7377395                                                徐若瑄        3
# 7377396                                            missing        3
# 7377397                                        Yi Jia Yang        3
# 7377398                                                阿弟仔        3
# 7377399                                                易家揚        3
# 7377400                                                陳鎮川        3
# 7377401                                                張震嶽        3
# 7377402                                            missing       52
# 7377403                                            missing       52
# 7377404                                            missing       52
# 7377405                                            missing       52
# 7377406                                            missing       -1
# 7377407                                            missing        3
# 7377408                                            missing       52
# 7377409                                            missing       52
# 7377410                                            missing       52
# 7377411                                            missing       52
# 7377412                                            missing       52
# 7377413                                            missing       52
# 7377414  Theron Thomas| Timothy Thomas| Lukasz Gottwald...       52
# 7377415               姚中仁 MC HotDog 陳昱榕 Ｅ-SO 周文傑 KENZY 林睦淵        3
# 7377416                                            missing       52
# 7377417                  Robert Andrew Hyman| Cyndy Lauper       52
#
#                                             name  unique_song_id  \
# 0                                     Good Grief           74679
# 1                             Lords of Cardboard          223479
# 2        Hip Hop Is Dead(Album Version (Edited))          120758
# 3                                   Disco Africa           23707
# 4                              Sleep Without You           33308
# 5                                          Panda           30191
# 6                     眼| 鼻| 口 (Eyes| Nose| Lips)          190019
# 7                               Star Of The Show          221827
# 8                              Dreaming Out Loud            9180
# 9                                 Counting Stars           93827
# 10                                 We Are Giants          320952
# 11                                  輕輕 (Lightly)           58110
# 12             手心的薔薇 (Beautiful) feat. G.E.M.鄧紫棋          327118
# 13                                      給我一首歌的時間          177669
# 14                                 關鍵詞 (The Key)          116775
# 15                 You Are My Everything - Gummy           46910
# 16                孤獨的總和 (Accumulated Loneliness)          214276
# 17                                           春天裡          321715
# 18                               因你而在 (You N Me)           37462
# 19                                       雨天 (雨天)           67851
# 20                      EGO-HOLIC戀我癖 (EGO-HOLIC)          190534
# 21                                           愛死你          107375
# 22                                           麥來亂          280590
# 23                                       Imagine          249090
# 24                           Give Peace A Chance          287261
# 25             You've Got To Hide Your Love Away          192955
# 26                           Across The Universe          176573
# 27                                          Baby           70810
# 28                                           安靜了          264949
# 29                                         Intro           81097
# ...                                          ...             ...
# 7377388                                      獨角戲           21862
# 7377389                                    單身≠失戀          176620
# 7377390                       我愛過你 (I Loved You)          295291
# 7377391                   不完美心跳 (Lost Heartbeat)          222005
# 7377392                                    寄袂出的批          145783
# 7377393                                       手指          350943
# 7377394                                This Love           20124
# 7377395                                     來愛我啦           95189
# 7377396                                  無與倫比的美麗          345640
# 7377397                           遇見 (Encounter)          333608
# 7377398                                      飛高高          177398
# 7377399                                       三月          162996
# 7377400                                       自虐          301518
# 7377401                                    跑車與坦克          170060
# 7377402      Light It Up (feat. Nyla & Fuse ODG)           64634
# 7377403                              True Colors          290720
# 7377404                                   Temple           98007
# 7377405                                 Unsteady          341373
# 7377406                                   Longer          353238
# 7377407                                     母系社會           17003
# 7377408                          How Far I'll Go           98275
# 7377409                          How Far I'll Go          302930
# 7377410                        Harder To Breathe          212251
# 7377411                         Don't Wanna Know          331761
# 7377412                            Love Somebody           15247
# 7377413                             Still D.R.E.          187659
# 7377414                              Locked Away          354712
# 7377415                                  FLY OUT           51546
# 7377416                               Wonderwall          102430
# 7377417                          Time after time          123573
#
#          unique_user_id  registration_init_year  registration_init_month  \
# 0                  8158                    2012                        1
# 1                 17259                    2011                        5
# 2                 17259                    2011                        5
# 3                 17259                    2011                        5
# 4                  8158                    2012                        1
# 5                  8158                    2012                        1
# 6                 17259                    2011                        5
# 7                  8158                    2012                        1
# 8                 28058                    2011                       11
# 9                 28058                    2011                       11
# 10                28058                    2011                       11
# 11                28058                    2011                       11
# 12                14921                    2015                        8
# 13                 2643                    2011                        2
# 14                14921                    2015                        8
# 15                 2643                    2011                        2
# 16                14921                    2015                        8
# 17                14921                    2015                        8
# 18                14921                    2015                        8
# 19                28126                    2013                        9
# 20                28126                    2013                        9
# 21                28126                    2013                        9
# 22                28126                    2013                        9
# 23                25914                    2015                       12
# 24                25914                    2015                       12
# 25                25914                    2015                       12
# 26                25914                    2015                       12
# 27                16130                    2010                       12
# 28                16130                    2010                       12
# 29                15462                    2010                        8
# ...                 ...                     ...                      ...
# 7377388           22966                    2014                       12
# 7377389           22966                    2014                       12
# 7377390           26892                    2012                       12
# 7377391           16570                    2016                        1
# 7377392            7721                    2008                       11
# 7377393            7721                    2008                       11
# 7377394           24467                    2011                        3
# 7377395           24467                    2011                        3
# 7377396           24467                    2011                        3
# 7377397            6443                    2014                        8
# 7377398           13585                    2005                        7
# 7377399           13585                    2005                        7
# 7377400           13585                    2005                        7
# 7377401           17110                    2013                        4
# 7377402            6775                    2006                        3
# 7377403            6775                    2006                        3
# 7377404            6775                    2006                        3
# 7377405           26319                    2011                        3
# 7377406           27665                    2014                        1
# 7377407           12942                    2013                       12
# 7377408           25515                    2010                       10
# 7377409           25515                    2010                       10
# 7377410           22511                    2017                        1
# 7377411           22511                    2017                        1
# 7377412           22511                    2017                        1
# 7377413            4211                    2004                       12
# 7377414           18266                    2013                        6
# 7377415           18266                    2013                        6
# 7377416            1216                    2015                        2
# 7377417            1216                    2015                        2
#
#          registration_init_date  expiration_year  expiration_month  \
# 0                             2             2017                10
# 1                            25             2017                 9
# 2                            25             2017                 9
# 3                            25             2017                 9
# 4                             2             2017                10
# 5                             2             2017                10
# 6                            25             2017                 9
# 7                             2             2017                10
# 8                             7             2018                 3
# 9                             7             2018                 3
# 10                            7             2018                 3
# 11                            7             2018                 3
# 12                            6             2017                 9
# 13                           21             2017                 9
# 14                            6             2017                 9
# 15                           21             2017                 9
# 16                            6             2017                 9
# 17                            6             2017                 9
# 18                            6             2017                 9
# 19                           12             2017                 9
# 20                           12             2017                 9
# 21                           12             2017                 9
# 22                           12             2017                 9
# 23                           20             2017                 9
# 24                           20             2017                 9
# 25                           20             2017                 9
# 26                           20             2017                 9
# 27                            5             2018                 1
# 28                            5             2018                 1
# 29                           12             2017                 9
# ...                         ...              ...               ...
# 7377388                      24             2017                 9
# 7377389                      24             2017                 9
# 7377390                      26             2017                10
# 7377391                      15             2017                 9
# 7377392                      29             2017                10
# 7377393                      29             2017                10
# 7377394                       6             2017                 9
# 7377395                       6             2017                 9
# 7377396                       6             2017                 9
# 7377397                      17             2017                 9
# 7377398                       3             2017                10
# 7377399                       3             2017                10
# 7377400                       3             2017                10
# 7377401                      27             2017                10
# 7377402                       2             2017                 9
# 7377403                       2             2017                 9
# 7377404                       2             2017                 9
# 7377405                      16             2017                 9
# 7377406                      12             2017                 9
# 7377407                       4             2017                 9
# 7377408                      14             2017                10
# 7377409                      14             2017                10
# 7377410                       5             2017                10
# 7377411                       5             2017                10
# 7377412                       5             2017                10
# 7377413                      18             2017                 9
# 7377414                      27             2017                10
# 7377415                      27             2017                10
# 7377416                      13             2017                 9
# 7377417                      13             2017                 9
#
#          expiration_date_  age_of_account  genre_count  composer_count  \
# 0                       5               5            1               2
# 1                      11               6            1               0
# 2                      11               6            1               1
# 3                      11               6            1               1
# 4                       5               5            1               3
# 5                       5               5            1               2
# 6                      11               6            1               3
# 7                       5               5            1               3
# 8                       4               7            1               1
# 9                       4               7            1               1
# 10                      4               7            1               3
# 11                      4               7            1               1
# 12                     30               2            1               1
# 13                     22               6            1               1
# 14                     30               2            2               1
# 15                     22               6            1               1
# 16                     30               2            1               1
# 17                     30               2            1               1
# 18                     30               2            1               1
# 19                     12               4            1               1
# 20                     12               4            1               1
# 21                     12               4            1               1
# 22                     12               4            1               0
# 23                     30               2            1               1
# 24                     30               2            1               2
# 25                     30               2            1               2
# 26                     30               2            1               0
# 27                      4               8            1               5
# 28                      4               8            1               1
# 29                     12               7            0               1
# ...                   ...             ...          ...             ...
# 7377388                 3               3            1               1
# 7377389                 3               3            1               1
# 7377390                 6               5            1               1
# 7377391                14               1            1               1
# 7377392                 1               9            1               0
# 7377393                 1               9            1               0
# 7377394                12               6            1               1
# 7377395                12               6            1               1
# 7377396                12               6            1               0
# 7377397                 9               3            1               1
# 7377398                31              12            1               1
# 7377399                31              12            1               1
# 7377400                31              12            1               1
# 7377401                 3               4            1               1
# 7377402                30              11            1               0
# 7377403                30              11            1               3
# 7377404                30              11            1               0
# 7377405                30               6            1               5
# 7377406                30               3            1               0
# 7377407                 8               4            1               1
# 7377408                 3               7            1               1
# 7377409                 3               7            1               1
# 7377410                 5               0            1               2
# 7377411                 5               0            1               9
# 7377412                 5               0            1               4
# 7377413                30              13            1               4
# 7377414                 6               4            1               5
# 7377415                 6               4            1               1
# 7377416                18               2            1               0
# 7377417                18               2            1               2
#
#          lyricist_count  artist_count  ranked_artist
# 0                     0             1           1140
# 1                     0             2         303616
# 2                     0             1            289
# 3                     0             1              1
# 4                     0             1            427
# 5                     0             1           1692
# 6                     2             1           8188
# 7                     0             1           1172
# 8                     0             1           9211
# 9                     0             1           9211
# 10                    0             1            376
# 11                    1             1           9714
# 12                    1             1         115325
# 13                    1             1         186776
# 14                    1             1         115325
# 15                    1             2         303616
# 16                    1             1           5995
# 17                    0             1          82799
# 18                    1             1         115325
# 19                    1             1          31708
# 20                    0             1           6250
# 21                    1             1          14582
# 22                    0             1         182088
# 23                    0             1            715
# 24                    0             1            715
# 25                    0             1           1768
# 26                    0             1              1
# 27                    0             1          30621
# 28                    1             1          32411
# 29                    1             1          39252
# ...                 ...           ...            ...
# 7377388               0             1           4564
# 7377389               1             1          30798
# 7377390               1             1          49426
# 7377391               1             1          25521
# 7377392               0             1           3860
# 7377393               0             1           3860
# 7377394               0             2         303616
# 7377395               1             1           7423
# 7377396               0             1          47177
# 7377397               1             1          31708
# 7377398               1             1          82799
# 7377399               1             1          82799
# 7377400               1             1          82799
# 7377401               1             1          11734
# 7377402               0             1          11211
# 7377403               0             1            425
# 7377404               0             1            433
# 7377405               0             2         303616
# 7377406               0             1           3658
# 7377407               0             1          10630
# 7377408               0             2         303616
# 7377409               0             2         303616
# 7377410               0             1          55151
# 7377411               0             1          55151
# 7377412               0             1          55151
# 7377413               0             1            659
# 7377414               5             1           1010
# 7377415               1             1          25781
# 7377416               0             1             32
# 7377417               2             1             13
#
# [7377418 rows x 28 columns]

# %%
refined_train_X.dtypes
# Out:
# source_system_tab          category
# source_screen_name         category
# source_type                category
# city                       category
# bd                            int64
# gender                     category
# registered_via             category
# song_length                 float64
# genre_ids                  category
# artist_name                category
# composer                   category
# lyricist                   category
# language                   category
# name                       category
# unique_song_id                int32
# unique_user_id                int16
# registration_init_year        int64
# registration_init_month       int64
# registration_init_date        int64
# expiration_year               int64
# expiration_month              int64
# expiration_date_              int64
# age_of_account                int64
# genre_count                   int64
# composer_count                int64
# lyricist_count                int64
# artist_count                  int64
# ranked_artist                 int64
# dtype: object
